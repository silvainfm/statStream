# %%
# import libraries needed
import pyforest

# import the excel file or csv file
def get_data_from_excel(sheet, excelFileName):
        path_excel = excelFileName
        df = pd.read_excel(
            io = path_excel,
            engine = 'openpyxl',
            sheet_name = sheet)
        #df = df.astype(str)
        #df.set_index('Company', inplace=True)
        return df

thedata = get_data_from_excel('Sheet1', 'Excel')

# %%
all_cols = ['Company',
 'Job Title',
 'Website',
 'State',
 'Department Spend',
 'Industry Sector',
 'Key Products or Services',
 'Employee Count',
 'Annual Sales',
 'Locations',
 'IT Department Size',
 'IT Security Team Size',
 'Contact Center Seats',
 'Operating System',
 'Current ERP',
 'Cloud Service Provider',
 'Cybersecurity Responsibility',
 'Cyber Initiatives',
 'cyber',
 'Cloud Solutions Responsibility',
 'Cloud Initiatives',
 'cloud',
 'Digital Responsibility',
 'Digital Initiatives',
 'digital',
 'Data Management Responsibility',
 'Data Management Initiatives',
 'data',
 'Software / Application Development Responsibility',
 'Development Initiatives',
 'software',
 'Communication Systems Responsibility',
 'Communication Initiatives',
 'communication',
 'Network Systems Responsibility',
 'Network Initiatives',
 'network',
 'Consulting / Outsourcing Responsibility',
 'Consulting Initiatives',
 'consulting',
 'IT Leadership, Talent Management and Training Responsibility',
 'Leadership Initiatives',
 'IT',
 'Cybersecurity Solutions',
 'Which Cloud Solutions',
 'Digital Solutions',
 'Data Management Solutions',
 'Software / Application Development Solutions',
 'Communication Systems Solutions',
 'Network Systems Solutions',
 'Consulting / Outsourcing Solutions',
 'IT Leadership, Talent Management and Training Solutions']

newcols = ['cyber', 'cloud', 'digital', 'data', 'software', 
 'communication', 'network', 'consulting', 'IT']

# %%
# dictionary of keywords: cyber, ucaas, mobility, Data-center, cloud, vendors
keyword_dic = {'cyber' : ['ciso',
'chief security information officer',
'cyber security',
'cybersecurity',
'security',
'firewall',
'network firewall',
'information security',
'network security',
'ddos',
'pen test',
'penetration test',
'vulnerability assessment',
'cloud security',
'critical event management',
'data security',
'data center security',
'physical security',
'psaas',
'physical security as a service',
'surveillance',
'access control',
'baas',
'backup as a service',
'backup',
'dr',
'disaster recovery',
'draas',
'sd-wan',
'encryption',
'endpoint',
'endpoint detection',
'endpoint prevention',
'muti-factor authentication',
'zerotrust',
'managed security provider',
'msaas',
'managed security as a service',
'sase',
'security access service edge',
'ransomware',
'ransomware protection',
'ddos',
'distributed denial of service',
'ddos protection',
'attacks',
'security solutions',
'siem',
'soc as a service',
'soc',
'security operations center',
'soar',
'security orchestration automation and response',
'threat intelligence',
'xdr',
'mdr',
'edr',
'arctic wolf',
'sentinel one',
'crowdstrike',
'carbon black',
'sophos',
'palo alto',
'atp',
'mssp',
'phishing',
'training',
'log management',
'threat management',
'governnence management',
'compliance',
'compliancy',
'compliance as a service',
'security posture management',
'configuration management',
'log management',
'threat management',
'governance management for public cloud',
'ayload-based signature protection',
'edge ml-powered intrusion detection and prevention',
'edge ml-powered malware protection',
'url filtering',
'compliance management',
'vulnerability management',
'container security and image scanning',
'serverless function security',
'runtime application self protection',
'cloud user & entity behavioral analytics',
'vulnerability scanning – internal',
'file integrity monitoring (fim)',
'edge-to-endpoint protection',
'user behavioral analytics',
'endpoint detection and response',
'fileless attack prevention',
'script execution engine',
'vulnerability scanning – internal',
'file integrity monitoring (fim)',
'add-on options - available for all levels',
'endpoint behavioral threat prevention',
'endpoint malware and antivirus protection',
'managed patching',
'additional waf protected',
'websites',
'additional waf login protect',
'users high availability (ha)',
'dr environment monitoring'],
'ucaas_ccaas' : ['ucaas',
'unified communications as a service',
'unified communications',
'sip',
'sip trunking',
'phone system',
'hosted phone system',
'cloud pbx',
'voip',
'voice over ip',
'voice over internet protocol',
'hosted voip',
'telephony',
'vonage',
'8x8',
'ringcentral',
'avaya',
'mitel',
'dialpad',
'zoom',
'nextiva',
'broadsoft',
'bandwidth.com',
'transcription',
'api',
'crm integration',
'shoretel',
'zoom',
'teams',
'microsoft teams',
'communications system',
'soft phone',
'enterprise voice',
'cloud communications',
'on-prem',
'on prem','ccaas',
'hosted contact center',
'call center management',
'contact center management',
'enterprise contact center',
'contact center',
'contact center solutions',
'contact center platform',
'call center',
'call center solutions',
'call center platform',
'customer service solution',
'call routing',
'ivr',
'chat solutions',
'omnichannel',
'chat solution',
'call analytics',
'wfm',
'workforce management',
'wfo',
'workforce optimization',
'five9',
'genesys',
'purecloud',
'talkdesk',
'nice',
'avaya',
'nortel',
'shortel',
'sharpen',
'cisco uccx',
'verint',
'uccx',
'customer experience',
'kpi',
'csat',
'outsourcing',
'sourcing strategy',
'rfp',
'bpo',
'mulit-channel',
'digitization'],
'mobility' : ['mobile deployment',
'mobile staging',
'kitting',
'provisioning',
'mobileiron',
'maas360',
'soti',
'vmware airwatch',
'meraki',
'mdm',
'mobile security',
'vz wireless',
't mobile',
'at&t',
'sprint',
'hotspots',
'solar winds',
'mobile device management',
'tem',
'telephone expense management',
'intune',
'mobile security management',
'iot', 'endpoint management',
'mfa','mobile help desk',
'mobile procurement',
'smartphones','tablets','jamf'],
'data_center':
['applicationfirst', 'digital', 'digitaltransformation', 'fintech', 
'insurtech', 'ai', 'rpa', 'appintegration', 'edgecomputing',
'bigdata', 'cybersecurity', 'iot', 'datascience', 'cloud', 
'devops', 'appdesign', 'multicloud', 'azure' 'aws', 'awsops', 
'containers', 'kubernetes', 'infrastructure', 'interconnection', 
'cloudcomputing', 'gcp', 'cicd', 'sre'],
'vendors': ['ringcentral', 'ring', 'zoom', 'cisco', 'teams', 'microsoft teams',
'mitel', 'shoretel'], 
'cloud': ['access control list', 'acl', 'aws', 'amazon web services', 'application modernization',
'api', 'application programming interface', 'application refactoring', 'ai', 'artificial intelligence',
'auto-scaling', 'availability zones', 'AZs',
'big data', 'blockchain', 'cloud', 'cloud application', 
'cloud computing', 'cloud migration', 'cloud-native', 
'cloud service provider', 'cluster', 
'compute', 'containers', 'content delivery network',
'cdn', 'continuous integration/continuous development', 'ci', 'cd',
'database', 'instance', 'data lake', 'data pipeline',
'data stream', 'devops', 'docker', 'docker image', 
'elastic computing', 'endpoint', 'etl', 'extract, transform, and load',
'google cloud', 'hadoop', 'high availability', 'hosted application', 
'hybrid cloud', 'infrastructure-as-a-service', 'iaas',
'internet of things', 'iot', 'json', 'javascript object notation', 
'kubernets', 'load balancing', 'machine learning', 'managed service provider', 
'msp', 'management and governance', 'microservices', 
'microsoft azure', 'multicloud', 'multi-tenant', 'orchestration', 
'private cloud', 'public cloud', 'representational state transfer',
'scalability', 'schema', 'software-as-a-service', '(saas)', 
'security, identity, and compliance', 'serverless computing',
'storage', 'virtualization', 'virtual machine', 
'virtual private cloud']}

# Functions for data analysis

# get all row containing list of keywords
def get_allrows(df, keylist):
    new_df = df[df.stack().str.contains('|'.join(keylist)).any(level=0)]
    return new_df 

# sort a df by a specific column
def sort_df(df, column):
    df.sort_values(by = column, inplace = True, ascending = True)
    return df

# function to set index before exporting
def setindex(df, columnI):
    df = df.set_index(columnI)
    return df

# getting the keyword count per category
def getkcount(df, category, listcol):
    for col in listcol:
        df[col+'_'+category+'_kcount'] = sum([df[col].str.contains(keyword) for keyword in keyword_dic[category]]).astype(float)
    df = df.fillna(0)
    # getting total kcount 
    df[category+'_total_kcount'] = (df['cyber_'+category+'_kcount'] + df['cloud_'+category+'_kcount'] + 
    df['digital_'+category+'_kcount'] + df['data_'+category+'_kcount'] + df['software_'+category+'_kcount'] +
    df['communication_'+category+'_kcount'] + df['network_'+category+'_kcount'] + 
    df['consulting_'+category+'_kcount'] + df['IT_'+category+'_kcount']) # improve this with list comprehension
    # delete not needed columns
    df.drop(columns = ['cyber_'+category+'_kcount', 'cloud_'+category+'_kcount', 'digital_'+category+'_kcount', 
    'data_'+category+'_kcount', 'software_'+category+'_kcount', 'communication_'+category+'_kcount', 
    'network_'+category+'_kcount', 'consulting_'+category+'_kcount', 'IT_'+category+'_kcount'], inplace = True)
    # sort total keyword count by highest count
    df = df.sort_values(by = [category+'_total_kcount'], inplace = True, ascending = False)
    return df

# get the total kcount based on a count parameter
def loc_total_kcount(df, category, count): 
    df = df.loc[(df[category + '_total_kcount'] > count)]
    return df
# Out:
# <ipython-input-4-0db39d4bd965>:263: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col+'_'+category+'_kcount'] = sum([df[col].str.contains(keyword) for keyword in keyword_dic[category]]).astype(float)
# <ipython-input-4-0db39d4bd965>:263: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col+'_'+category+'_kcount'] = sum([df[col].str.contains(keyword) for keyword in keyword_dic[category]]).astype(float)
# <ipython-input-4-0db39d4bd965>:263: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[col+'_'+category+'_kcount'] = sum([df[col].str.contains(keyword) for keyword in keyword_dic[category]]).astype(float)
# ...

# %%
thecategory = 'cyber' # or cloud, mobility, ucaas_ccaas, data_center, vendors
button = "st button pressed by user"
if button: 
    df = getkcount(thedata, thecategory, newcols)

# %%
chase_full = setindex(chase_overall, 'Company')

writer = pd.ExcelWriter('8.3.analysis.xlsx', engine='xlsxwriter')

# move the different dfs to excel 

chase_full.to_excel(writer, sheet_name = 'Overall')

writer.save()
